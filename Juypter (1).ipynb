# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ahmed Wagdy**
#
# Supply chain design manager

# %% [markdown]
# *I am interested in Data science because I would like to leverage availabe data to obtain results that can be of benefit to the human beings*

# %% [markdown]
# ### Simple code that shows basic multiplication

# %%
x = 3*3

x
# Out:
# 9

# %% [markdown]
# coding on IBM watson is awesom!
#
# ____
# 1. I have used here the Horizontal rule
# 2. I have used here the numbered list
#
# * and finally....
# * .
